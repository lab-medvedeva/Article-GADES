# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data_python.csv')
weight=[]
unID=[]
w1=[]
w2=[]
# This is for Matrix.bench file Real Dataset
# for i in df['DataFile']:
#     k= i.split('/')[-1].rsplit('_',1)[0]
#     i = i.split("_")
#     i=i[-1].split(".")[0]
#     weight.append(int(i))
#     unID.append(k)

#This is for Generated dataset
for i in df['name']:
    k=i.split('/')[-1].split('_')
    i= i.split("_")
    w1.append(int(k[0]))
    w2.append(int(k[2]))

df['wX'] = w1
df['wY'] = w2
df['logWX'] = np.log10(df['wX'])
df['logWY'] = np.log10(df['wY'])
# df['weight'] = weight
# #df['minTime'] = df[['val_1':'val_25']].min(axis=1)
# df['logW'] = np.log10(df['weight'])
df['logMeanTime'] = np.log10(df['mean_norm'])
df['logMinTime']=np.log10(df['min_norm'])
df['logMaxTime']=np.log10(df['max_norm'])
df['|W|'] = df['wX']*df['wY']
#df['IDtag'] = unID
#print(df[df['DataFile']])
for i in df['name']:
    k=i.split('/')[-1].split('_')
    i= i.split("_")
    print(i,k)
ma=[]
for i in df['name']:
    m=i.split('/')[-1].split('.')
    ma.append(m[0])
c=0
# for j in df['method']:
#     ma[c]= ma[c]+'_'+j
#     c+=1
# c=0
# for k in df['metric']:
#     ma[c]= ma[c]+'_'+k
#     c+=1

#df['W']=ma
df
# Out:
# ['../../DistanceBenchmarking/Generated/100', 'cells', '100000', 'genes.csv'] ['100', 'cells', '100000', 'genes.csv']
# ['../../DistanceBenchmarking/Generated/100', 'cells', '100000', 'genes.csv'] ['100', 'cells', '100000', 'genes.csv']
# ['../../DistanceBenchmarking/Generated/100', 'cells', '100000', 'genes.csv'] ['100', 'cells', '100000', 'genes.csv']
# ['../../DistanceBenchmarking/Generated/100', 'cells', '10000', 'genes.csv'] ['100', 'cells', '10000', 'genes.csv']
# ['../../DistanceBenchmarking/Generated/100', 'cells', '100000', 'genes.csv'] ['100', 'cells', '100000', 'genes.csv']
# ['../../DistanceBenchmarking/Generated/100', 'cells', '10000', 'genes.csv'] ['100', 'cells', '10000', 'genes.csv']
# ['../../DistanceBenchmarking/Generated/100', 'cells', '10000', 'genes.csv'] ['100', 'cells', '10000', 'genes.csv']
# ['../../DistanceBenchmarking/Generated/100', 'cells', '10000', 'genes.csv'] ['100', 'cells', '10000', 'genes.csv']
# ...

# %%
dfa = pd.read_csv('generatedData_bench_100iter.csv')
cols = []
for i in range(1,25):
    cols.append('val_{}'.format(i))
dfa['minTime'] =dfa[cols].min(axis=1)
dfa['maxTime']=dfa[cols].max(axis=1)
dfa

weight=[]
unID=[]
w1=[]
w2=[]
# This is for Matrix.bench file Real Dataset
# for i in dfa['DataFile']:
#     k= i.split('/')[-1].rsplit('_',1)[0]
#     i = i.split("_")
#     i=i[-1].split(".")[0]
#     weight.append(int(i))
#     unID.append(k)

#This is for Generated dataset
for i in dfa['DataFile']:
    k=i.split('/')[-1].split('_')
    i= i.split("_")
    w1.append(int(k[0]))
    w2.append(int(k[2]))

dfa['wX'] = w1
dfa['wY'] = w2
dfa['logWX'] = np.log10(dfa['wX'])
dfa['logWY'] = np.log10(dfa['wY'])
# dfa['weight'] = weight
# #dfa['minTime'] = dfa[['val_1':'val_25']].min(axis=1)
# dfa['logW'] = np.log10(dfa['weight'])
dfa['logMeanTime'] = np.log10(dfa['mean'])
dfa['logMinTime']=np.log10(dfa['minTime'])
dfa['logMaxTime']=np.log10(dfa['maxTime'])
dfa['|W|'] = dfa['wX']*dfa['wY']
#dfa['IDtag'] = unID
#print(dfa[dfa['DataFile']])
dfa

for i in dfa['DataFile']:
    k=i.split('/')[-1].split('_')
    i= i.split("_")
    print(i,k)
ma=[]
for i in dfa['DataFile']:
    m=i.split('/')[-1].split('.')
    ma.append(m[0])
c=0
# for j in dfa['method']:
#     ma[c]= ma[c]+'_'+j
#     c+=1
# c=0
# for k in dfa['metric']:
#     ma[c]= ma[c]+'_'+k
#     c+=1

#dfa['W']=ma
dfa
#Remove anomalies
dfa.drop(dfa[dfa['logWX']==5.0].index,inplace=True)
# Out:
# ['../DistanceBenchmarking/Generated/100', 'cells', '100000', 'genes.csv'] ['100', 'cells', '100000', 'genes.csv']
# ['../DistanceBenchmarking/Generated/100', 'cells', '100000', 'genes.csv'] ['100', 'cells', '100000', 'genes.csv']
# ['../DistanceBenchmarking/Generated/100', 'cells', '100000', 'genes.csv'] ['100', 'cells', '100000', 'genes.csv']
# ['../DistanceBenchmarking/Generated/100', 'cells', '100000', 'genes.csv'] ['100', 'cells', '100000', 'genes.csv']
# ['../DistanceBenchmarking/Generated/100', 'cells', '100000', 'genes.csv'] ['100', 'cells', '100000', 'genes.csv']
# ['../DistanceBenchmarking/Generated/100', 'cells', '100000', 'genes.csv'] ['100', 'cells', '100000', 'genes.csv']
# ['../DistanceBenchmarking/Generated/100', 'cells', '10000', 'genes.csv'] ['100', 'cells', '10000', 'genes.csv']
# ['../DistanceBenchmarking/Generated/100', 'cells', '10000', 'genes.csv'] ['100', 'cells', '10000', 'genes.csv']
# ...

# %%
dfa[dfa['method']=='factoextra']
# Out:
#     Column1                                           DataFile      method  \
# 56       56  ../DistanceBenchmarking/Generated/100_cells_10...  factoextra
# 57       57  ../DistanceBenchmarking/Generated/10000_cells_...  factoextra
# 58       58  ../DistanceBenchmarking/Generated/100_cells_10...  factoextra
# 59       59  ../DistanceBenchmarking/Generated/10000_cells_...  factoextra
# 60       60  ../DistanceBenchmarking/Generated/1000_cells_1...  factoextra
# 61       61  ../DistanceBenchmarking/Generated/10_cells_100...  factoextra
# 62       62  ../DistanceBenchmarking/Generated/10_cells_100...  factoextra
# 63       63  ../DistanceBenchmarking/Generated/10_cells_100...  factoextra
# 64       64  ../DistanceBenchmarking/Generated/1000_cells_1...  factoextra
# 65       65  ../DistanceBenchmarking/Generated/10000_cells_...  factoextra
# 66       66  ../DistanceBenchmarking/Generated/10000_cells_...  factoextra
# ...

# %%
dfr = pd.DataFrame()
dfr['method'] = df['metric']+'_'+df['method']
dfr['cells'] = df['logWX']
dfr['peaks'] = df['logWY']
dfr['time'] = df['logMeanTime']

# %%
dfl= pd.DataFrame()
dfl['method'] = dfa['metric']+'_'+dfa['method']
dfl['cells'] = dfa['logWX']
dfl['peaks'] = dfa['logWY']
dfl['time'] = dfa['logMeanTime']
dfl = dfl.append(dfr,ignore_index=True)
dfl
# Out:
#                  method  cells  peaks      time
# 0        euclidean_amap    2.0    5.0  6.334081
# 1          pearson_amap    2.0    5.0  6.426811
# 2          kendall_amap    2.0    5.0  8.046439
# 3         euclidean_GPU    2.0    5.0  5.718123
# 4           pearson_GPU    2.0    5.0  5.815651
# ..                  ...    ...    ...       ...
# 143      pearson_pandas    4.0    2.0  7.367072
# 144    euclidean_pandas    4.0    2.0  8.608858
# 145  euclidean_pythonic    4.0    2.0  8.687251
# 146    pearson_pythonic    4.0    2.0  8.659418
# 147    kendall_pythonic    4.0    2.0  8.673153
#
# [148 rows x 4 columns]

# %%
#df = pd.read_csv('results.csv')
dfl[dfl['method']=='euclidean_factoextra']
# Out:
#                   method  cells  peaks      time
# 56  euclidean_factoextra    2.0    4.0  7.548870
# 57  euclidean_factoextra    4.0    3.0  7.487083
# 59  euclidean_factoextra    1.0    4.0  6.649155
# 62  euclidean_factoextra    3.0    4.0  8.632948
# 63  euclidean_factoextra    4.0    1.0  3.472606
# 66  euclidean_factoextra    2.0    3.0  5.511592
# 71  euclidean_factoextra    4.0    2.0  5.465887
# 72  euclidean_factoextra    3.0    3.0  6.473440

# %%
df_gpu = df[df.method == 'euclidean_GPU']
df_amap = df[df.method == 'euclidean_amap']
df_cpu = df[df.method == 'euclidean_CPU']
df_factoextra = df[df.method == 'euclidean_factoextra']
df_pythonic = df[df.method == 'euclidean_pythonic']
df_pandas = df[df.method == 'euclidean_pandas']

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.colors import BoundaryNorm

# %%
cmap = plt.get_cmap()

# %%
cmap.N
# Out:
# 256

# %%
norm_p      = BoundaryNorm(np.linspace(3, 11.0, 19), ncolors=cmap.N, clip=True)

# %%
method = 'euclidean'
method_lower = method.lower()

# %%
df =dfl
dfl.to_csv('data_isotherm.csv')

# %%
df = df.dropna()

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(32, 8))
fig.suptitle(f'{method} Isotherms', fontsize=24)
fig.tight_layout(h_pad=5)
current_df = df[df.method == f'{method_lower}_GPU']

current_axis = ax[0][0]
current_axis.set_title('GPU', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.set_xlabel('Log num genes', fontsize=18)
current_axis.set_ylabel('Log num cells', fontsize=18)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)
contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_CPU']
print(current_df)
current_axis = ax[0][1]
current_axis.set_title('CPU', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.set_xlabel('Log num genes', fontsize=18)
current_axis.set_ylabel('Log num cells', fontsize=18)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)
# fig.colorbar(tcf)
contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_amap']
current_axis = ax[2][0]
current_axis.set_title(f'amap', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.set_xlabel('Log num genes', fontsize=18)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
# current_axis.set_ylabel('Log num cells', fontsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)
contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_factoextra']
print(current_df)
current_axis = ax[1][0]
current_axis.set_title('Factoextra', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
# current_axis.set_ylabel('Log num cells', fontsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)

contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_pythonic']
print(current_df)
current_axis = ax[1][1]
current_axis.set_title('Pythonic', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
# current_axis.set_ylabel('Log num cells', fontsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)

contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_pandas']
print(current_df)
current_axis = ax[2][1]
current_axis.set_title('Pandas', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
# current_axis.set_ylabel('Log num cells', fontsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)

contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

fig.colorbar(tcf, ax=ax)
plt.savefig(f'Isotherm{method}.png', bbox_inches='tight')
# Out:
#            method  cells  peaks      time
# 76  euclidean_CPU    1.0    4.0  3.497183
# 78  euclidean_CPU    2.0    3.0  4.032297
# 81  euclidean_CPU    2.0    4.0  4.996017
# 84  euclidean_CPU    2.0    5.0  5.990833
# 85  euclidean_CPU    3.0    3.0  6.001403
# 90  euclidean_CPU    3.0    4.0  6.978622
# 91  euclidean_CPU    4.0    1.0  6.425663
# 94  euclidean_CPU    4.0    2.0  7.185764
# 96  euclidean_CPU    4.0    3.0  8.574805
#                   method  cells  peaks      time
# 56  euclidean_factoextra    2.0    4.0  7.548870
# 57  euclidean_factoextra    4.0    3.0  7.487083
# 59  euclidean_factoextra    1.0    4.0  6.649155
# 62  euclidean_factoextra    3.0    4.0  8.632948
# 63  euclidean_factoextra    4.0    1.0  3.472606
# 66  euclidean_factoextra    2.0    3.0  5.511592
# 71  euclidean_factoextra    4.0    2.0  5.465887
# 72  euclidean_factoextra    3.0    3.0  6.473440
#                  method  cells  peaks      time
# 101  euclidean_pythonic    2.0    5.0  6.361213
# ...

# %%
method = 'pearson'
method_lower = method.lower()

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(32, 8))
fig.suptitle(f'{method} Isotherms', fontsize=24)
fig.tight_layout(h_pad=5)
current_df = df[df.method == f'{method_lower}_GPU']

current_axis = ax[0][0]
current_axis.set_title('GPU', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.set_xlabel('Log num genes', fontsize=18)
current_axis.set_ylabel('Log num cells', fontsize=18)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)
contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_CPU']
print(current_df)
current_axis = ax[0][1]
current_axis.set_title('CPU', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.set_xlabel('Log num genes', fontsize=18)
current_axis.set_ylabel('Log num cells', fontsize=18)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)
# fig.colorbar(tcf)
contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_amap']
current_axis = ax[2][0]
current_axis.set_title(f'amap', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.set_xlabel('Log num genes', fontsize=18)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
# current_axis.set_ylabel('Log num cells', fontsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)
contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_factoextra']
print(current_df)
current_axis = ax[1][0]
current_axis.set_title('Factoextra', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
# current_axis.set_ylabel('Log num cells', fontsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)

contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_pythonic']
print(current_df)
current_axis = ax[1][1]
current_axis.set_title('Pythonic', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
# current_axis.set_ylabel('Log num cells', fontsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)

contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_pandas']
print(current_df)
current_axis = ax[2][1]
current_axis.set_title('Pandas', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
# current_axis.set_ylabel('Log num cells', fontsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)

contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

fig.colorbar(tcf, ax=ax)
plt.savefig(f'Isotherm{method}.png', bbox_inches='tight')
# Out:
#          method  cells  peaks      time
# 73  pearson_CPU    4.0    2.0  7.900352
# 75  pearson_CPU    2.0    4.0  5.368214
# 77  pearson_CPU    3.0    4.0  7.572292
# 80  pearson_CPU    1.0    4.0  3.645157
# 82  pearson_CPU    4.0    3.0  8.651441
# 86  pearson_CPU    2.0    5.0  6.378504
# 88  pearson_CPU    2.0    3.0  4.379367
# 89  pearson_CPU    4.0    1.0  6.808528
# 93  pearson_CPU    3.0    3.0  6.447823
#                 method  cells  peaks      time
# 54  pearson_factoextra    2.0    4.0  7.208593
# 55  pearson_factoextra    4.0    3.0  6.945318
# 58  pearson_factoextra    3.0    4.0  7.906375
# 60  pearson_factoextra    1.0    4.0  6.485769
# 64  pearson_factoextra    4.0    1.0  3.288681
# 65  pearson_factoextra    2.0    3.0  5.066481
# 69  pearson_factoextra    4.0    2.0  4.940378
# 70  pearson_factoextra    3.0    3.0  5.913256
#                method  cells  peaks      time
# 98   pearson_pythonic    2.0    5.0  6.307138
# ...

# %%
method = 'kendall'
method_lower = method.lower()

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(32, 8))
fig.suptitle(f'{method} Isotherms', fontsize=24)
fig.tight_layout(h_pad=5)
current_df = df[df.method == f'{method_lower}_GPU']

current_axis = ax[0][0]
current_axis.set_title('GPU', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.set_xlabel('Log num genes', fontsize=18)
current_axis.set_ylabel('Log num cells', fontsize=18)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)
contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_CPU']
print(current_df)
current_axis = ax[0][1]
current_axis.set_title('CPU', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.set_xlabel('Log num genes', fontsize=18)
current_axis.set_ylabel('Log num cells', fontsize=18)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)
# fig.colorbar(tcf)
contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_amap']
current_axis = ax[2][0]
current_axis.set_title(f'amap', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.set_xlabel('Log num genes', fontsize=18)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
# current_axis.set_ylabel('Log num cells', fontsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)
contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

# current_df = df[df.method == f'{method_lower}_factoextra']
# print(current_df)
# current_axis = ax[1][0]
# current_axis.set_title('Factoextra', fontsize=20)
# current_axis.set_xlim(1.0, 5.0)
# current_axis.set_ylim(1.0, 5.0)
# current_axis.tick_params(axis='x', labelsize=18)
# current_axis.tick_params(axis='y', labelsize=18)
# # current_axis.set_ylabel('Log num cells', fontsize=18)
# tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)

contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_pythonic']
print(current_df)
current_axis = ax[1][1]
current_axis.set_title('Pythonic', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
# current_axis.set_ylabel('Log num cells', fontsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)

contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

current_df = df[df.method == f'{method_lower}_pandas']
print(current_df)
current_axis = ax[2][1]
current_axis.set_title('Pandas', fontsize=20)
current_axis.set_xlim(1.0, 5.0)
current_axis.set_ylim(1.0, 5.0)
current_axis.tick_params(axis='x', labelsize=18)
current_axis.tick_params(axis='y', labelsize=18)
# current_axis.set_ylabel('Log num cells', fontsize=18)
tcf = current_axis.tricontourf(current_df.peaks,current_df.cells,current_df.time, norm=norm_p)

contour = current_axis.tricontour(current_df.peaks,current_df.cells,current_df.time, colors='k', norm=norm_p)

fig.colorbar(tcf, ax=ax)
plt.savefig(f'Isotherm{method}.png', bbox_inches='tight')
# Out:
#          method  cells  peaks      time
# 74  kendall_CPU    1.0    4.0  7.025762
# 79  kendall_CPU    2.0    3.0  6.966574
# 83  kendall_CPU    2.0    4.0  8.959992
# 87  kendall_CPU    3.0    3.0  8.680020
# 92  kendall_CPU    4.0    1.0  7.025120
# 95  kendall_CPU    4.0    2.0  9.084278
#                method  cells  peaks      time
# 105  kendall_pythonic    2.0    4.0  5.274256
# 106  kendall_pythonic    2.0    5.0  6.218334
# 116  kendall_pythonic    1.0    4.0  5.038158
# 118  kendall_pythonic    3.0    4.0  7.109711
# 125  kendall_pythonic    4.0    3.0  8.760396
# 130  kendall_pythonic    4.0    1.0  8.603342
# 136  kendall_pythonic    2.0    3.0  5.074018
# 142  kendall_pythonic    3.0    3.0  6.751754
# 147  kendall_pythonic    4.0    2.0  8.673153
#              method  cells  peaks      time
# 107  kendall_pandas    2.0    4.0  6.779002
# 113  kendall_pandas    1.0    4.0  4.808888
# 119  kendall_pandas    2.0    5.0  7.717210
# ...
